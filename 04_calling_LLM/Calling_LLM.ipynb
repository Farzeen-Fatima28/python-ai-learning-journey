# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Tell me who invented samosa in 3 lines"
    )

print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# The samosa was not invented by a single person but originated in the medieval Middle East and Central Asia as a meat-filled pastry called *sanbosag*.
# It was introduced to the Indian subcontinent by migrant traders, merchants, and cooks during the Delhi Sultanate in the 13th and 14th centuries.
# Indian chefs then adapted the recipe, filling it with local spices and vegetables like potatoes to create the iconic snack we know today.

# %%
  ingredients = ["dal", "onion", "tomatoes"]
  ','.join(ingredients)  # → 'dal,onion,tomatoes'
# Out:
# 'dal,onion,tomatoes'

# %%
from google import genai
client = genai.Client()

# 1. Define the function with its 3 parameters:

def generate_recipe(ingredients, cuisine, diet):

# 2. Add the docstring (the '''...''' explanation right after):
    '''
    Generate a recipe using ingredients provided.
    Cuisine can be "Italian", "Mexican", "Indian", "Pakistani" etc.
    diet can be "Vegan", "Vegeterian", "Jain", "Any" etc.
    '''

#3. Build the prompt using an f-string:    
    prompt = f'''
    Generate one food receipe using these ingredients: {','.join(ingredients)}
    Receipe should not be more than 100 words
    Cuisine: {cuisine}
    Diet: {diet}
    '''

    response = client.models.generate_content(
        model="gemini-3.5-flash",
        contents=prompt
    )
    return response.text

# %%
print(generate_recipe(["dal", "onion", "tomatoes"], "Indian", "Vegan"))
# Out:
# **Easy Indian Tomato Dal**
#
# Boil 1 cup of washed yellow dal with 3 cups of water, salt, and a pinch of turmeric until soft.
#
# In a pan, heat 1 tablespoon of vegetable oil. Sauté 1 chopped onion until translucent. Add 2 chopped tomatoes and cook until soft and mushy.
#
# Pour the boiled dal into the pan, mix well, and simmer for 5 minutes. Season with salt to taste. Serve hot with rice or flatbread.

# %%
print(generate_recipe(["Corns", "black Beans", "Avocado"], "Mexican", "Vegan"))
# Out:
# **Vegan Mexican Corn & Bean Salad**
#
# *   1 cup black beans, rinsed
# *   1 cup sweet corn (canned or fresh)
# *   1 ripe avocado, diced
# *   Juice of 1 lime
# *   2 tbsp chopped fresh cilantro
# *   Pinch of salt and chili powder
#
# **Instructions:**
# In a bowl, combine the black beans, corn, and diced avocado. Drizzle with fresh lime juice. Sprinkle the cilantro, salt, and chili powder on top. Gently toss the ingredients together so the avocado stays intact. Serve immediately as a refreshing salad, taco filling, or dip with tortilla chips.
